# %%
import os
import re
import requests
import pandas as pd

# %%
def extract_movie_titles(root_path):
    movie_titles = []

    # Supported video file extensions
    video_extensions = ['.mp4', '.mkv', '.avi', '.mov','.flv']

    for root, dirs, files in os.walk(root_path):
        for file in files:
            if any(file.endswith(ext) for ext in video_extensions):
                # Extracting filename without extension
                title = os.path.splitext(file)[0]
                movie_titles.append(title)

    return movie_titles

# %%
def clean_title(title):
    # A series of regular expressions to clean up the title
    patterns = [
        r'\[.*?\]',  # Remove anything in square brackets
        r'\(.*?\)',  # Remove anything in round brackets
        r'1080p|720p|480p',  # Remove common resolutions
        r'BluRay|DVD|HDRip|HD',  # Remove release types
        r'film completo',  # Specific phrases
        r'Full Movie by Film&Clips',
        r'by .*$',  # 'by' and everything that follows
        r'Versione Restaurata',
        r'Subtitle',
        r'Film',
        r'Full',
        r'Pelicula Completa',
        r'IN ITALIANO',
        r'Movie',
        r'(?<![a-zA-Z])-(?![a-zA-Z])',  # Remove dashes not between words
        # r'\d{4}.*$',  # Remove any four digits (like 1985) and everything that follows
    ]
    
    for pattern in patterns:
        # re.IGNORECASE makes the regex pattern case insensitive
        title = re.sub(pattern, '', title, flags=re.IGNORECASE)
    
    # Replacing underscores with space
    title = title.replace('_', ' ')
    
    title = title.strip()  # Remove any leading/trailing whitespace
    return title

# %%
movie_list = extract_movie_titles('D:/Films')

# %%
movie_list = [clean_title(movie) for movie in movie_list]

# %%
movie_list
# Out:
# ['Frankenweenie',
#  'Il Castello Errante di Howl',
#  'La sposa cadavere',
#  'The nightmare before Christmas 1993',
#  'The Polar Express 2004',
#  'Il Grande Nord',
#  'Jason and The Argonauts',
#  '. Distretto 13',
#  'Agente 007 Licenza di uccidere, 1962',
#  'Clint Eastwood  Dove Osano Le Aquile 1969',
#  'Dalla Russia Con Amore',
#  'Diabolik',
#  'Distretto 13',
#  'I guerreri della notte',
#  "I tre dell'operazione Drago",
#  'Il Braccio Violento della Legge',
#  'Il Furore Della Cina Colpisce Ancora',
#  "Indiana Jones e i Predatori Dell'arca Perduta",
#  'Indiana Jones e il Tempio Maledetto',
#  'La ghigliottina volante',
#  "Ocean's eleven",
#  'Quel maledetto treno blindato',
#  "Un colpo all'italiana",
#  'Fist Of Fury 1972',
#  'Il furore della cina colpisce ancora',
#  "L'ultimo combattimento di Chen",
#  'The Way of The Dragon 1972',
#  'Banditi a Milano1968',
#  'Cani arrabbiati',
#  'Il Caso Venere Privata 1970',
#  "Il cinico l'infame il violento",
#  'Il Grande Racket',
#  'La morte risale a ieri sera',
#  'La Polizia Chiede Aiuto',
#  'La polizia ha le mani legate',
#  'La polizia ringrazia',
#  'La via della droga, 1977',
#  'Liberi armati pericolosi',
#  'Milano odia la polizia non può sparare',
#  'Napoli violenta',
#  'Revolver',
#  'Squadra antiscippo 1976',
#  'Uomini Si Nasce Poliziotti Si Muore  1976',
#  'I Padroni della città',
#  'I Ragazzi del Massacro  un  di Fernando Di Leo',
#  'Il Boss',
#  'Il poliziotto è marcio  di Fernando Di Leo',
#  'La Mala Ordina',
#  'Milano Calibro 9',
#  '. A History of violence',
#  '. Il metronotte',
#  ". L'inquilino del terzo piano",
#  '. The Departed',
#  ". Una Squillo Per L'ispettore Klute",
#  '13 Tzameti',
#  'Chi ucciderà Charlie Varrick 1973',
#  'Cittadino X',
#  'Delitto in pieno sole',
#  'Duel',
#  "Faccia D'Angelo",
#  'I senza nome',
#  'I tre giorni del condor',
#  'Il Giustiziere Della Notte',
#  'Il maratoneta',
#  'Il metronotte',
#  "Il mistero dell'acqua",
#  'Il Nome Della Rosa',
#  'Ispettore Callaghan  Il Caso Scorpio è Tuo',
#  "L'alibi era perfetto",
#  "L'inquilino del terzo piano",
#  "L'Ultimo Treno Della Notte 1975",
#  'La Parola ai Giurati 1957',
#  'Niente da nascondere',
#  'Nikita',
#  'Notturno Bus',
#  'Piramide di paura',
#  'Rischio totale',
#  'The Departed',
#  'Ultimo Domicilio Conosciuto 1970',
#  'Un tranquillo weekend di paura',
#  "Una Squillo Per L'ispettore Klute",
#  'Uno Bianca',
#  'Vestito per uccidere 1980',
#  'Zodiac 2007',
#  'The Game 1997',
#  'Il posto delle fragole',
#  'Il Settimo Sigillo, 1956',
#  'Il volto, 1958',
#  "L'ora del lupo, 1967",
#  'La Fontana Della Vergine',
#  "Luci D'Inverno, 1962",
#  'Monica e il desiderio  1953',
#  "Sinfonia D'Autunno, 1978",
#  "Sorrisi di una notte d'estate",
#  '. Gli anni della violenza',
#  '. Il Caso Antonino Gioè',
#  '. La stazione di Bologna',
#  '. La tangente Enimont',
#  '. La uno bianca',
#  'Blu Notte  Le Brigate Rosse parte 1',
#  'Blu Notte  Le Brigate Rosse parte 2',
#  'Blu Notte 2011  Le morti silenziose  Blu notte',
#  'Genova 2001 G8',
#  'GLADIO',
#  'Gli anni della violenza',
#  'Il Caso Antonino Gioè',
#  'Il Caso Enrico Mattei',
#  'Il Caso Salvatore Giuliano',
#  'Il clan dei Casalesi',
#  'Il naufragio fantasma',
#  'La Mafia al Nord',
#  'La mattanza',
#  'La stazione di Bologna',
#  'La storia della camorra',
#  'La Storia Della Ndrangheta',
#  'La strage di Piazza Fontana',
#  'La tangente Enimont',
#  'La uno bianca',
#  'Messina, un enigma da decifrare',
#  'Michele Sindona',
#  'Milano Calibro 9',
#  'Pasolini',
#  'Strage di Ustica',
#  'Blu notte  Misteri italiani La Violenza negli Anni 70 1di2  Video Dailymotion',
#  'Blu notte  Misteri italiani La Violenza negli Anni 70 2di2  Video Dailymotion',
#  'Agata',
#  'Anna Laura',
#  'Aurora',
#  'Elisa e Patrizio',
#  'Gianfranco',
#  'I Delitti Del Mostro Di Firenze',
#  'I misteri di Alleghe',
#  "L'omicidio Di Via Caravaggio",
#  'La Grotta Della Croara',
#  'Mara',
#  'Massimo',
#  'MISTERO IN BLU   il caso Nada Cella',
#  'Simonetta Il Delitto Della Cattolica',
#  'Stevanin',
#  'Arsenico e vecchi merletti',
#  'Baci rubati',
#  'Effetto Notte',
#  'Fantomas 70',
#  'Goodbye Lenin',
#  'Il senso della vita',
#  'La Brillante Carriera Di Un Giovane Vampiro',
#  'Monty Python and the Holy Grail 1975',
#  'Paura e delirio a Las Vegas, 1998',
#  'Per favore non mordermi sul collo',
#  'Signori il delitto e servito 1985',
#  'Un topolino sotto sfratto',
#  'Boccaccio',
#  'Come fu che Masuccio Salernitano, fuggendo con le brache in mano, riuscì a conservarlo sano',
#  'Decameron n. 2  Le altre novelle del Boccaccio',
#  'Decameron n° 4   Le belle novelle del Boccaccio 1972',
#  'Decameron Proibitissimo Boccaccio Mio Statte Zitto',
#  'Fra Tazio da Velletri 1973',
#  'Fratello Homo, Sorella Bona',
#  "L'ultimo Decameron  Le più belle donne del Boccaccio",
#  'Metti lo diavolo tuo ne lo mio inferno',
#  'RACCONTI PROIBITI  DI NIENTE VESTITI 1972',
#  '. Fantozzi',
#  'Fantozzi',
#  'Fantozzi Contro Tutti',
#  'Fantozzi va in pensione',
#  'Il Secondo Tragico Fantozzi',
#  '. Febbre da Cavallo',
#  'Amici Miei Atto I',
#  'Amici Miei Atto II',
#  'Audace colpo dei soliti ignoti 1959',
#  "C'eravamo Tanto Amati,",
#  'Continuavano a chiamarlo Trinità',
#  'FANTASMI A ROMA',
#  'Febbre da Cavallo',
#  'I Soliti Ignoti 1958',
#  'Il Sorpasso',
#  'In Nome Del Papa Re',
#  'In nome del popolo italiano',
#  'La Grande Abbuffata',
#  'La Più Bella Serata Della Mia Vita',
#  'Le avventure di Pinocchio',
#  'Lo chiamavano Trinità',
#  "Matrimonio all'Italiana",
#  "Nell'Anno Del Signore 1969",
#  'Quando Le Donne Si Chiamavano Madonne',
#  'Racconti Romani',
#  'Romanzo Popolare',
#  'Signore E Signori',
#  'Squadra Antitruffa',
#  'Straziami ma di baci saziami',
#  'Tutti Defunti... Tranne I Morti',
#  'Venga a prendere il caffe da noi',
#  'Vogliamo I Colonnelli',
#  '. Ma quando arrivano le ragazze',
#  '. Non ci Resta che Piangere',
#  '. Regalo di Natale',
#  'Ad Ovest Di Paperino',
#  'Baci E Abbracci, 1999',
#  'Borotalco',
#  'Caterina Va In Città',
#  'Compagni Di Scuola',
#  'Eccezzziunale... veramente',
#  'Gli Amici Del Bar Margherita 2009',
#  'Il Bi e il Ba',
#  'Il Bisbetico Domato',
#  'Il Conte Tacchia 1982',
#  'Il marchese del Grillo',
#  'Il ragazzo di campagna',
#  'Il Ras Del Quartiere',
#  'Io, Chiara e Lo Scuro',
#  "L'Allenatore Nel Pallone",
#  'La Rivincita Di Natale',
#  "Madonna Che Silenzio c'e Stasera",
#  'Marrakech Express',
#  'Non ci Resta che Piangere',
#  'Ovo sodo',
#  'Pranzo di Ferragosto',
#  'Puerto escondido',
#  'Regalo di Natale',
#  'Stregati',
#  'Un Sacco Bello',
#  'Vieni Avanti Cretino',
#  'Yuppies.',
#  'Basta che funzioni',
#  'Crimini e misfatti',
#  'Harry a pezzi',
#  'Il Dittatore dello Stato libero di Bananas',
#  'Io e Annie',
#  'Manhattan',
#  'Misterioso Omicidio A Manhattan',
#  'Prendi i soldi e scappa',
#  'Bowling A Columbine',
#  'Commodore C64  1982',
#  'DARIO ARGENTO PRESENTA 4 MOSCHE DI VELLUTO GRIGIO   UNA PRESENTAZIONE VIDEO MANIAC',
#  'Il Crack della Parmalat',
#  'Il grande silenzio 2005',
#  'Kalachakra, La Ruota Del Tempo',
#  'Lezioni di cinema. Il cinema secondo Dario Argento',
#  'Manufacturing Consent',
#  'Sicko',
#  'The corporation',
#  'The war on democracy',
#  'Erhard Loretan, breathing the smell of the sky (en',
#  'Gasherbrum 1984',
#  'In nome della Montagna',
#  'K2 Sogno e destino',
#  "l'Eco del Silenzio",
#  'La morte sospesa',
#  'Reinhold Messner 2018',
#  'Chernobyl Anatoly Dyatlov’s real interview',
#  'Chernobyl- Quark puntata completa  Paco Lanciano',
#  'Scariest room in Chernobyl Abandoned Ghost City  Chernobyl 2.0 PART 2',
#  'The Real Chernobyl',
#  'Zero Hour  Disaster at Chernobyl Discovery Channel',
#  "Faites entrer l'accusé L'affaire Rezala  S5  Ep8",
#  "Faites entrer l'accusé La French connection  S6 EP9",
#  "Faites entrer l'accusé Pierre Chanal  S2  Ep5",
#  "Faites entrer l'accusé  Alexi à Louveciennes  S4 Ep9",
#  "Faites entrer l'accusé  Bruno Cholet, Le faux taxi  S18  Ep5",
#  "Faites entrer l'accusé  Bruno Joushomme  S6  Ep5",
#  "Faites entrer l'accusé  David Jandin et Joao Soares   S11  Ep15",
#  "Faites entrer l'accusé  Florence Rey, Audry Maupin  S4  Ep2",
#  "Faites entrer l'accusé  Francisco Arce Montes S6 Ep1",
#  "Faites entrer l'accusé  Jamila Belkacem  S5  Ep14",
#  "Faites entrer l'accusé  Karine Torchi  S13  Ep9",
#  "Faites entrer l'accusé  L'énigme Alfred Petit  S8  Ep3",
#  "Faites entrer l'accusé  Les postiches  S5  Ep3",
#  "Faites entrer l'accusé  Louis Poirson",
#  "Faites entrer l'accusé  Luc Amblard et Guy Bordenave  S14  Ep7",
#  "Faites entrer l'accusé  Magali Guillemot",
#  "Faites entrer l'accusé  Marc Dutroux  Ep8",
#  "Faites entrer l'accusé  Marcel Barbeault  S5  Ep2",
#  "Faites entrer l'accusé  Marie-Elisabeth Cons-Boutboul, secrets de famille  S1  Ep6",
#  "Faites entrer l'accusé  Myriam Badaoui, le juge et la menteuse  Outreau  S8  Ep12",
#  "Faites entrer l'accusé  Nadine et Jérôme  S8  Ep2",
#  "Faites entrer l'accusé  Nicolas Charbonnier  S20  Ep2",
#  "Faites entrer l'accusé  Paul Touvier, la traque  S7  EP5",
#  "Faites entrer l'accusé  Pierre Bodein, Pierrot le fou  S6  Ep3",
#  "Faites entrer l'accusé  Pierre Dubois  S5  Ep9",
#  "Faites entrer l'accusé  Raphael Maillant  S 20 EP3",
#  "Faites entrer l'accusé  Roland Cazaux, le chat  S7  Ep2",
#  "Faites entrer l'accusé  Thierry Paulin  S4 Ep8",
#  "Faites entrer l'accusé  Thierry Saman, le concierge qui en savait trop S15-Ep6",
#  "Faites entrer l'accusé  Ulrich Muenstermann  S14 Ep12",
#  "Faites entrer l'accusé  Jean-Claude Romand  le menteur",
#  "Faites entrer l'accusé  Roberto Succo, Succo le fou",
#  'Faites entrer l-accusé La disparition de Christophe Dalmasso  S15 Ep2 -FELA 204',
#  'Faites entrer l-accusé Robert Lund- le mystère du lac -FELA 182 S13 Ep16',
#  "Les frères Jourdain, meutres au carnaval  Faites entrer l'accusé #FELA",
#  'documentario i delitti del mostro di Firenze',
#  'HC  Il mostro di Firenze',
#  'il mostro di Firenze Italia 7',
#  "La vicenda del Mostro di Firenze che tra il 1968 ed il 1985 terrorizzò l'Italia  Prima parte",
#  "La vicenda del Mostro di Firenze che tra il 1968 ed il 1985 terrorizzò l'Italia  Seconda parte",
#  "Mostro  Firenze Identikit di un'assassino  trasmissione del 16.9.1985",
#  'mostro di firenze  pacciani MIXER 1995',
#  'mostro firenze',
#  'Nuove indagini sul Mostro di Firenze.Nero Toscana',
#  'Rarissimo Documentario Sul Mostro Di Firenze',
#  '5 pezzi facili',
#  'A 30 secondi dalla fine',
#  'Americani',
#  'Billy Elliot',
#  'Black swan',
#  'Dogman',
#  'Dreams',
#  'Easy Rider',
#  'Elephant',
#  'Fargo',
#  'Fight Club 1999',
#  "Fino all'ultimo respiro",
#  'Fucking Amal  Il Coraggio Di Amare',
#  'Fuga Dalla Scuola Media',
#  'Giorni Perduti',
#  'Hooligans',
#  'I Daniel Blake',
#  "I Racconti della Luna Pallida d'Agosto",
#  'Il fascino discreto della borghesia',
#  'Il Laureato',
#  'Il Ponte Sul Fiume Kwai',
#  'In un mondo migliore',
#  "L'enigma di Kaspar Hauser",
#  "L'uomo senza sonno",
#  'La Vita è Meravigliosa',
#  'Le luci della sera',
#  'Le Vite Degli Altri',
#  'Nordwand',
#  'Orwell 1984',
#  'Paris, Texas',
#  'Picnic Ad Hanging Rock',
#  'Qualcuno Volò Sul Nido Del Cuculo  1975',
#  'Quarto Potere',
#  'Rambo First Blood',
#  'Rocky',
#  'Sogni e delitti',
#  'Stalker 1979',
#  'Stand',
#  'Taxi Driver',
#  'The Wild Bunch',
#  'The Wrestler',
#  'Via da Las Vegas',
#  'Apocalypse Now 1979',
#  ". MIGNON E' PARTITA",
#  'Amore Tossico',
#  'Anima persa',
#  'Banditi a Orgosolo',
#  'Bisturi, la mafia bianca',
#  'Blow-Up',
#  'Cadaveri eccellenti',
#  'Concorrenza sleale',
#  'Deserto Rosso 1964',
#  'Francesco, giullare di Dio',
#  'Giorni E Nuvole',
#  'Hanno cambiato faccia 1971',
#  'I Banchieri di Dio',
#  'I cento passi',
#  'Il giorno della civetta',
#  'Il Grido',
#  'Il partigiano Johnny',
#  'Il Portiere Di Notte',
#  "Il Posto dell'anima",
#  'Io La Conoscevo Bene',
#  'Io non ho paura',
#  "L' Eclisse",
#  "L'imbalsamatore",
#  "L'ultimo sapore dell'aria",
#  'La battaglia di Algeri',
#  'La cena per farli conoscere',
#  'La Notte',
#  'La ragazza del lago',
#  'Le mani sulla città',
#  'Mery Per Sempre',
#  'Mi piace lavorare  Mobbing',
#  'Mia madre',
#  "MIGNON E' PARTITA",
#  'Ossessione',
#  'Otto e mezzo',
#  'Per grazia ricevuta  1971',
#  'Primo Amore',
#  'Ragazzi Fuori',
#  'Riso Amaro',
#  'Sacco E Vanzetti',
#  'San Babila ore 20 un delitto inutile',
#  'Sbatti il mostro in prima pagina 1972',
#  'Segreti Di Stato  Portella Della Ginestra',
#  'Strana la vita',
#  'Un bellissimo novembre',
#  'Un borghese piccolo piccolo',
#  'Un eroe borghese',
#  'Una Giornata Particolare',
#  'Uomini Contro',
#  'Vajont',
#  'Il Giardino dei Finzi Contini',
#  'Ladri di Biciclette Vittorio De Sica   1948',
#  'Sciuscià -V. De Sica ,1946 Eng. Subs',
#  'Umberto D  1952',
#  'A ciascuno il suo  di Elio Petri',
#  'Elio Petri  La classe operaia va in paradiso',
#  'Indagine Su Un Cittadino Al Di Sopra Di Ogni Sospetto',
#  'Un Tranquillo Posto Di Campagna  Elio Petri',
#  'Lunacy',
#  'stroszek 1977',
#  'Sweeney Todd 2007',
#  'Alien',
#  'Blade Runner',
#  'Dark City',
#  'Gremlins',
#  'Il Cavaliere Oscuro',
#  'Il Labirinto Del Fauno',
#  'Il Pianeta Proibito',
#  "L'Implacabile 1987",
#  'La città perduta',
#  'La Decima Vittima 1970',
#  'La Storia Infinita',
#  'Nel fantastico mondo di Oz',
#  'Solaris 1972',
#  'Terminator',
#  'Terrore nello spazio',
#  'Willy Wonka e la Fabbrica di cioccolato',
#  'Hobbit 1 Un viaggio inaspettato',
#  'Hobbit 2 La desolazione di Smaug',
#  'Hobbit 3 La battaglia delle cinque armate',
#  'Roma CD1',
#  'Roma CD2',
#  "L'Ours",
#  'Le Diner de Cons 1998',
#  'Moi, Christiane F.',
#  'Rabbi Jacob',
#  "L'emploi du temps",
#  ". Chi L'ha Vista Morire",
#  ". Giornata Nera Per L'Ariete",
#  '. I Corpi presentano Tracce di Violenza Carnale',
#  ". L'occhio Nel Labirinto",
#  '. La coda dello scorpione',
#  '. Macchie Solari  Autopsy    1973',
#  '. Non si sevizia un paperino',
#  ". Nude per l'assassino",
#  ". Sei Donne Per L'Assassino",
#  "5 Bambole per la Luna d'Agosto",
#  "Chi L'ha Vista Morire",
#  'Cosa avete fatto a Solange',
#  'E Tanta Paura',
#  'I Corpi presentano Tracce di Violenza Carnale',
#  'Il gatto dagli occhi di giada',
#  'Il profumo della signora in nero',
#  "L'occhio Nel Labirinto",
#  'La coda dello scorpione',
#  'La corta notte delle bambole di vetro',
#  'La donna del lago',
#  'La donna della domenica',
#  'La morte accarezza a mezzanotte',
#  'La morte bussa due volte',
#  "La morte ha fatto l'uovo",
#  'La Morte Risale a Ieri Sera',
#  'La ragazza che sapeva troppo',
#  'La Tarantola dal ventre nero, 1972',
#  'La vittima designata',
#  'Macchie Solari 1973',
#  'Mio caro assassino',
#  'Non si deve profanare il sonno dei morti 1974',
#  'Non si sevizia un paperino',
#  "Nude per l'assassino",
#  'Paranoia',
#  'Passi Di Danza Su Una Lama Di Rasoio',
#  'Perché Quelle Strane Gocce Di Sangue Sul Corpo Di Jennifer, 1972',
#  "Sei Donne Per L'Assassino",
#  'Sette Orchidee Macchiate Di Rosso',
#  'SETTE SCIALLI DI SETA GIALLA',
#  'Solamente nero',
#  'Spasmo',
#  'Tutti i colori del buio',
#  'Una farfalla con le ali insanguinate 1971',
#  'Una Lucertola con la Pelle di Donna',
#  "Una sull'altra",
#  'Caccia al Ladro',
#  'Complotto di famiglia',
#  'Frenzy',
#  "I prigionieri dell'oceano",
#  'Il delitto perfetto',
#  'Il ladro',
#  'Il sospetto',
#  'Intrigo Internazionale',
#  'Io ti salvero',
#  "L'altro uomo",
#  "L'uomo che sapeva troppo",
#  'La congiura degli innocenti',
#  'La Donna Che Visse Due Volte 1958',
#  'La finestra sul cortile',
#  'La Signora Scompare',
#  'Marnie',
#  'Nodo alla gola',
#  'Psyco',
#  'Rebecca  La prima moglie',
#  'Shadow of a Doubt',
#  '. Dream Home 2010 FR',
#  '1408',
#  'ALTA TENSIONE',
#  'Ammazzavampiri',
#  'Angst',
#  'Babadook 2014',
#  'Calvaire',
#  'Dark Water 2002',
#  'Dead of Night  Incubi notturni',
#  'Dream Home 2010',
#  'Il mistero di Sleepy Hollow',
#  'Il Mostro Di Dusseldorf',
#  'Il Ritorno Dei Morti Viventi',
#  'Il seme della follia',
#  'Il Tagliaerbe',
#  "L'esorcista",
#  "L'uomo Dagli Occhi A Raggi X",
#  'La Casa 1',
#  'La casa dei fantasmi 1958',
#  'La Casa Dei Mille Corpi',
#  'La Casa Del Diavolo',
#  'La Cosa',
#  'La Maschera di Frankenstein',
#  'Lasciami entrare',
#  'Le Colline Hanno Gli Occhi',
#  'Night Of The Comet',
#  'Night of the Living Dead  1968',
#  'Nightmare  Dal profondo della notte ]',
#  'Nightmare 2  La Vendetta',
#  'Nightmare 3 I guerrieri del sogno',
#  'Non aprite quella porta',
#  'Nosferatu  Il principe della notte',
#  'Ragazzi Perduti',
#  'Re-Animator 1985',
#  'Repulsion 1965',
#  "Salem's Lot 1979",
#  'Searching 2018',
#  'Shutter',
#  'the bad seed 1956',
#  'The Blair Witch Project',
#  'The Legend Of Hell House 1973',
#  'The Vanishing 1988',
#  'The Wicker Man',
#  'Un Lupo Mannaro Americano A Londra',
#  'Zombie',
#  'Brood  La covata malefica',
#  'eXistenZ',
#  'La Mosca, 1986',
#  'Rabid  Sete di sangue',
#  'Shivers',
#  'Videodrome',
#  'Dracula',
#  'The Exorcist III',
#  'Halloween II 1981',
#  '28° minuto',
#  'Buio Omega',
#  'Danza macabra',
#  'Dellamorte Dellamore',
#  "Demoni 2 L'incubo Ritorna",
#  'Dove comincia la notte',
#  "Firenze...L'Assassino è Ancora Tra Noi",
#  'Il mostro di Firenze',
#  'Il Mulino Delle Donne Di Pietra',
#  'Incubo Sulla Città Contaminata',
#  'La Dama Rossa Uccide Sette Volte',
#  'La Morte Negli Occhi Del Gatto',
#  'La notte che Evelyn uscì dalla tomba',
#  'La Notte dei Demoni  1988',
#  'La Notte Dei Diavoli 1972',
#  'Le Notti del Terrore 1981',
#  'Pensione Paura',
#  'Road To L. 2005',
#  '4 mosche di velluto grigio',
#  'Il gatto a nove code',
#  'Inferno 1980',
#  "L'Uccello Dalle Piume Di Cristallo 1970",
#  'Opera',
#  'Phenomena 1985',
#  'Profondo Rosso 1975',
#  'Suspiria 1977',
#  'Tenebre 1982',
#  ". L'arcano incantatore",
#  '. La Casa Dalle Finestre Che Ridono',
#  '. Zeder',
#  'Il Signor Diavolo',
#  "L'arcano incantatore",
#  'La Casa Dalle Finestre Che Ridono',
#  'Zeder',
#  'I Tre Volti della Paura',
#  'Il rosso segno della follia',
#  'La Frusta e il Corpo',
#  'La maschera del demonio, 1960',
#  'Operazione paura',
#  'Demoni',
#  "E tu vivrai nel terrore! l'Aldila)",
#  'Paura Nella Citta dei Morti Viventi',
#  'Quella villa accanto al cimitero',
#  'Sette Note in Nero 1977',
#  'Jigoku 1960',
#  'Tesis 1996',
#  'The Changeling 1980',
#  'The House of The Devil 2009',
#  'The Wailing 2016',
#  '. Arancia meccanica',
#  '2001 A Space Odyssey',
#  'Arancia meccanica',
#  'Barry Lindon',
#  'metal jacket',
#  'Il dottor stranamore',
#  'Orizzonti di gloria',
#  'Rapina a Mano Armata',
#  'Shining',
#  '. La.messa.é.finita.1985.',
#  'Bianca',
#  'Ecce Bombo',
#  'Habemus Papam',
#  'Il Caimano',
#  'La Messa e finita 1985',
#  'La stanza del figlio',
#  'Palombella rossa',
#  "Sogni d'oro 1981",
#  '. Il Corridoio della Paura   Samuel er',
#  'Ascensore Per Il Patibolo',
#  'Casablanca 1942',
#  'Chinatown',
#  'Gangsters',
#  'I diabolici',
#  'Il Corridoio della Paura',
#  'Il Falcone Maltese',
#  'Il Grande sonno 1946',
#  'Il Terzo Uomo 1949',
#  "L'infernale Quinlan",
#  "L'uomo Che Non C'era  2001",
#  'La Fiamma del Peccato 1944',
#  'La Morte Corre Sul Fiume',
#  'La Scala a Chiocciola',
#  'Cantando Dietro i Paraventi',
#  "Durante l'estate",
#  'I Fidanzati',
#  'Il mestiere delle Armi 1991',
#  'Il Posto',
#  'Il tempo si e fermato',
#  "L'Alberto degli Zoccoli",
#  'La Leggenda del Santo Bevitore',
#  'Un Certo Giorno',
#  'Accattone',
#  'I Racconti Di Canterbury',
#  'Il Decameron 1971',
#  'Il Vangelo secondo Matteo',
#  'PORCILE 1969',
#  'Salo o le 120 giornate di Sodoma',
#  'Ipotesi sulla scomparsa di un fisico atomico',
#  'Chernobyl.S01e01.Ita.Eng..h264.byMetalh',
#  'Chernobyl.S01e02.Ita.Eng..h264.byMetalh',
#  'Chernobyl.S01e03.Ita.Eng..h264.byMetalh',
#  'Chernobyl.S01e04.Ita.Eng..h264.byMetalh',
#  'Chernobyl.S01e05.Ita.Eng..h264.byMetalh',
#  "Dov'è Anna  7x7  M Rigillo, S Gabel, P Capponi",
#  'Dovè Anna  1x7  M Rigillo, S Gabel, P Capponi',
#  'Dovè Anna  2x7  M Rigillo, S Gabel, P Capponi',
#  'dovè anna  3x7  M Rigillo, S Gabel, P Capponi',
#  'dovè Anna  4x7  M Rigillo, S Gabel, P Capponi',
#  'Dovè Anna  5x7  M Rigillo, S Gabel, P Capponi',
#  'Dovè Anna  6x7  M Rigillo, S Gabel, P Capponi',
#  'I.Compagni.di.Baal..01..La.lanterna.di.Diogene',
#  'I.Compagni.di.Baal..02...I.misteri.dell&quot;isola.di.Saint.Louis',
#  'I.Compagni.di.Baal..03...Lo.Spettro.Rosso',
#  'I.Compagni.Di.Baal..04...L&quot;inquietante.Professor.Lomer',
#  'I.Compagni.di.Baal..05..La.notte.dell&quot;.Otto.di.Fiori',
#  'I.Compagni.di.Baal..06..L&quot;eredita&quot;.di.Nostradamus',
#  'I.Compagni.Di.Baal..07..Il.risveglio.di.Lilian',
#  'I racconti del faro  3x6 Il naufrago II',
#  'I racconti del faro  4x6 Luca il marinaio',
#  'I racconti del faro  5x6 Il segreto della bottiglia I',
#  'I racconti del faro  6x6 Il segreto della bottiglia II',
#  'I racconti del faro 1967  La tromba marina',
#  'I racconti del faro 1967 2x6 Il naufrago I',
#  'Il Segno Del Comando episodio 1',
#  'Il Segno Del Comando episodio 2',
#  'Il Segno Del Comando episodio 3',
#  'Il Segno Del Comando episodio 4',
#  'Il Segno Del Comando episodio 5',
#  'Jack the Ripper  Part 1',
#  'Jack the Ripper  Part 2',
#  "1. L'amaro caso della Baronessa di Carini",
#  "2. L'amaro caso della Baronessa di Carini",
#  "3. L'amaro caso della Baronessa di Carini",
#  "4. L'amaro caso della Baronessa di Carini",
#  'La porta sul buio  Il tram  Dario Argento  1973',
#  'La porta sul buio  Il vicino di casa  Scritto da Dario Argento 1973',
#  'La porta sul buio  La bambola  Scritto da Dario Argento 1973',
#  'La porta sul buio  Testimone oculare  Scritto da Dario Argento 1973',
#  'NOTTURNO 1',
#  'NOTTURNO 2',
#  'NOTTURNO 3',
#  'NOTTURNO 4',
#  'NOTTURNO 5',
#  'NOTTURNO 6',
#  'NOTTURNO 7',
#  'The Office  1.1  Downsize',
#  'The Office  1.2  Work Experience',
#  'The Office  1.3  The Quiz',
#  'The Office  1.4  Training',
#  'The Office  1.5  New Girl',
#  'The Office  1.6  Judgement',
#  'The Office  2.1  Merger',
#  'The Office  2.2  Appraisals',
#  'The Office  2.3  Party',
#  'The Office  2.4  Motivation',
#  'The Office  2.5  Charity',
#  'The Office  2.6  Interview',
#  'The Office  Christmas Special Part 1',
#  'The Office  Christmas Special Part 2',
#  'The Office  Bloopers',
#  'The Office  Closed For Business',
#  "The Office  David Brent  If You Don't Know Me",
#  'The Office  Deleted Scenes',
#  'The Office  Documentary',
#  'The Office  Golden Globe Featurette',
#  'The Office  Video Diary Of The Making Of Series Two',
#  '1.Ritratto di donna velata',
#  '2.Ritratto di donna velata',
#  '3.Ritratto di donna velata',
#  '4.Ritratto di donna velata',
#  '5.Ritratto di donna velata',
#  'Episodio 00',
#  'Episodio 01',
#  'Episodio 02',
#  'Episodio 03',
#  'Episodio 04',
#  'Episodio 05',
#  'Episodio 06',
#  'Episodio 07',
#  'Episodio 0102',
#  'Episodio 03',
#  'Episodio 04',
#  'Episodio 05',
#  'Episodio 06',
#  'Episodio 07',
#  'Episodio 08',
#  'Episodio 09',
#  'Episodio 10',
#  'Episodio 11',
#  'Episodio 12',
#  'Episodio 13',
#  'Episodio 14',
#  'Episodio 15',
#  'Episodio 16',
#  'Episodio 17',
#  'Episodio 18',
#  'Episodio 19',
#  'Episodio 20',
#  'Episodio 21',
#  'Episodio 22',
#  'Episodio 23',
#  'VOCI NOTTURNE  prima puntata',
#  'VOCI NOTTURNE  quarta puntata',
#  'VOCI NOTTURNE  quinta puntata',
#  'VOCI NOTTURNE  seconda puntata',
#  'VOCI NOTTURNE  terza puntata',
#  'Il caso Mattei',
#  'Magnificat',
#  'Titanic latitudine 41 gradi nord  1958',
#  'Triumph des Willens',
#  'Tutti gli uomini del Presidente',
#  'Pinocchio  Bene',
#  "L'intervento a Telefono giallo Giovanni Falcone",
#  "Le stragi di Capaci e via d'Amelio Puntata Telefono Giallo, novembre 1992",
#  'Mostro di Firenze  Telefono giallo con Spezi, Federico, Iadevito, Filastò, Vigna, Maurri, Rotella',
#  'Telefono giallo  Furia omicida a Montesacro',
#  'Telefono giallo  Gisella Orru',
#  'Telefono giallo  Il caso della Baronessa De Magistris',
#  'Telefono giallo  Il caso Semerari',
#  'Telefono giallo  Il delitto Chichiarelli',
#  'Telefono giallo  Il delitto della Versilia',
#  'Telefono giallo  Il delitto delle bambine di Marsala parte 2 2',
#  'Telefono giallo  Il delitto di Palazzo Dario',
#  'Telefono giallo  Il delitto di Veio',
#  'Telefono Giallo  Il Delitto Di Via Poma',
#  "Telefono giallo  Il dirottamento dell'Achille Lauro",
#  "Telefono giallo  L'incredibile caso di Daniel Gin",
#  "Telefono giallo  L'omicidio di Paolo Di Nella",
#  'Telefono Giallo  La Strage di Ustica',
#  'TELEFONO GIALLO  LA STRAGE DI VIA CARAVAGGIO',
#  'Telefono Giallo  Le cento facce del caso Pecorelli',
#  'Telefono Giallo  Le misteriose sparizioni di Emanuela Orlandi e Mirella Gregori',
#  'Telefono giallo  Lultimo viaggio di Roberta',
#  'Telefono giallo  Un delitto quasi perfetto',
#  'Telefono giallo  Un mistero in fondo alla scala',
#  'TELEFONO GIALLO 1989 sul caso   trasmissione integrale',
#  'Telefono giallo Bologna  il delitto del DAMS',
#  'Telefono giallo Il caffè Sindona',
#  'Telefono giallo Il caso Calvi',
#  'Telefono giallo Il caso Pecorelli',
#  'Telefono giallo Il controverso caso Carlotto',
#  'Telefono giallo Il delitto ammaturo',
#  'Telefono giallo Il delitto del prof Montanari',
#  'Telefono giallo Il delitto della Versilia',
#  'Telefono giallo Il delitto di Parma',
#  'Telefono Giallo il Mostro di Firenze',
#  'Telefono giallo Il terzo uomo di Ludwig',
#  "Telefono giallo L'imprenditore e la maestra",
#  'Telefono giallo La medium di Treviso',
#  'Telefono giallo Palermo assassinio di un sindaco',
#  'Telefono giallo Rocco Chinnici, una strage annunciata 360p',
#  'Telefono giallo Speciale Ustica',
#  'Telefono giallo Tragico appuntamento per due bambine',
#  'Telefono giallo Un delitto quasi perfetto',
#  'Telefono giallo Un mistero in fondo alla scala',
#  'The Computer Chronicles  Computer Music',
#  'The Computer Chronicles  Computers in Education',
#  'The Computer Chronicles  Mainframes to Minis to Micros',
#  'The Computer Chronicles  Microchip Technology',
#  'The Computer Chronicles  Printers',
#  'The Computer Chronicles  Robotics',
#  'The Computer Chronicles  Simulator Software',
#  'The Computer Chronicles  Storage Devices',
#  'The Computer Chronicles  Word Processing',
#  'The Computer Chronicles  Artificial Intelligence',
#  'The Computer Chronicles  Business Application Software',
#  'The Computer Chronicles  Computer Entrepreneurs',
#  'The Computer Chronicles  Computer Ergonomics',
#  'The Computer Chronicles  Computer Games',
#  'The Computer Chronicles  Computer Graphics',
#  'The Computer Chronicles  Computer Security',
#  'The Computer Chronicles  Computers in Communications',
#  'The Computer Chronicles  Database Software',
#  'The Computer Chronicles  Decision Support Systems',
#  'The Computer Chronicles  Fifth Generation Computers',
#  'The Computer Chronicles  Japanese PCs',
#  'The Computer Chronicles  Lasers and Computers',
#  'The Computer Chronicles  Local Area Networks',
#  'The Computer Chronicles  Operating Systems',
#  'The Computer Chronicles  Programming',
#  'The Computer Chronicles  Speech Synthesis',
#  'The Computer Chronicles  Super Computers',
#  'The Computer Chronicles  Amiga and Atari',
#  'The Computer Chronicles  Artificial Intelligence',
#  'The Computer Chronicles  Business Applications',
#  "The Computer Chronicles  Christmas Buyer's Guide",
#  'The Computer Chronicles  Computer Games',
#  'The Computer Chronicles  Computer Graphics',
#  'The Computer Chronicles  Computer Networks',
#  'The Computer Chronicles  Computers & Medicine',
#  'The Computer Chronicles  Computers and Politics',
#  'The Computer Chronicles  Computers and the Disabled',
#  'The Computer Chronicles  Computers and the Media',
#  'The Computer Chronicles  Computers in Law Enforcement',
#  'The Computer Chronicles  Computers in Sports',
#  'The Computer Chronicles  Hard Disk Storage',
#  'The Computer Chronicles  IBM Clones',
#  'The Computer Chronicles  Low End Computers',
#  'The Computer Chronicles  Modems & Bulletin Boards',
#  'The Computer Chronicles  Optical Storage Devices',
#  'The Computer Chronicles  Personal Finance Software',
#  'The Computer Chronicles  Portable Computers',
#  'The Computer Chronicles  Printers and Business Graphics',
#  'The Computer Chronicles  Profile of Big Blue  IBM',
#  'The Computer Chronicles  Robots  Japanese Style',
#  'The Computer Chronicles  Slowdown in Silicon Valley #2',
#  'The Computer Chronicles  Slowdown in Silicon Valley 1',
#  'The Computer Chronicles  Software Piracy',
#  'The Computer Chronicles  The Macintosh Computer',
#  'The Computer Chronicles  UNIX',
#  'The Computer Chronicles  Women in Computing',
#  'The Computer Chronicles  Astronomy Software',
#  'The Computer Chronicles  Careers in Computing',
#  "The Computer Chronicles  Christmas Buyer's Guide",
#  'The Computer Chronicles  Comdex',
#  'The Computer Chronicles  Computers and the Pentagon Part 1',
#  'The Computer Chronicles  Computers and the Pentagon Part 2',
#  'The Computer Chronicles  Desktop Publishing Part 1',
#  'The Computer Chronicles  Desktop Publishing Part 2',
#  'The Computer Chronicles  Educational Software',
#  'The Computer Chronicles  Educational Software Part 2',
#  'The Computer Chronicles  Investment Software',
#  'The Computer Chronicles  MIDI Music',
#  'The Computer Chronicles  Parallel Processing',
#  'The Computer Chronicles  Project Management Software',
#  'The Computer Chronicles  Psychological Software',
#  'The Computer Chronicles  RAM Resident Software',
#  'The Computer Chronicles  Reduced Instruction Set Computer',
#  'The Computer Chronicles  Second Hand Computers',
#  'The Computer Chronicles  Utilities',
#  'The Computer Chronicles  Apple Local Area Networks',
#  'The Computer Chronicles  Asian Clones',
#  'The Computer Chronicles  Business Applications',
#  'The Computer Chronicles  Business Applications Part 2',
#  'The Computer Chronicles  Business Applications Part 4',
#  'The Computer Chronicles  Business Software for the Mac',
#  'The Computer Chronicles  Comdex 1987',
#  "The Computer Chronicles  Computer Buyer's Guide",
#  'The Computer Chronicles  Computer Games',
#  'The Computer Chronicles  Computer Kids',
#  'The Computer Chronicles  Computers & Illiteracy',
#  'The Computer Chronicles  Computers and Gambling',
#  'The Computer Chronicles  Computers and the Arts',
#  'The Computer Chronicles  Hypercard',
#  'The Computer Chronicles  IBM Compatible Local Area Networks',
#  'The Computer Chronicles  IBM Personal System 2',
#  'The Computer Chronicles  Intel 386  The Fast Lane',
#  'The Computer Chronicles  Intelligent Buildings',
#  'The Computer Chronicles  Laser Printers',
#  'The Computer Chronicles  On-Line Databases 2',
#  'The Computer Chronicles  Online Services Part 1',
#  'The Computer Chronicles  Portable Computers',
#  'The Computer Chronicles  Speech Recognition and Synthesis',
#  'The Computer Chronicles  Super Computers',
#  'The Computer Chronicles  Tax Preparation Software',
#  'The Computer Chronicles  The New Macs',
#  'The Computer Chronicles  Add-On Boards',
#  'The Computer Chronicles  Apple II Forever',
#  'The Computer Chronicles  BUS Wars',
#  'The Computer Chronicles  Business Graphics for the Mac',
#  'The Computer Chronicles  Business Graphics for the PC',
#  'The Computer Chronicles  CD ROMs',
#  'The Computer Chronicles  Comdex',
#  'The Computer Chronicles  Commodore 64',
#  'The Computer Chronicles  Computer Bowl I Part 1',
#  'The Computer Chronicles  Computer Bowl I Part 2',
#  'The Computer Chronicles  Computer Games',
#  'The Computer Chronicles  Computer Imaging and Digitizing',
#  "The Computer Chronicles  Consumer Buyer's Guide",
#  'The Computer Chronicles  Decision Support Software',
#  'The Computer Chronicles  Input Devices',
#  'The Computer Chronicles  Investment Software',
#  'The Computer Chronicles  Laptop Peripherals',
#  'The Computer Chronicles  MacWorld Boston',
#  'The Computer Chronicles  Multitasking',
#  'The Computer Chronicles  Personal CAD',
#  'The Computer Chronicles  Shareware',
#  'The Computer Chronicles  Spreadsheet Wars',
#  'The Computer Chronicles  Tax Preparation Software',
#  'The Computer Chronicles  The New Amigas',
#  'The Computer Chronicles  Amiga 3000',
#  'The Computer Chronicles  CD-ROM Software',
#  'The Computer Chronicles  Computer Bowl II Part 1',
#  'The Computer Chronicles  Computer Bowl II Part 2',
#  'The Computer Chronicles  Computer Viruses',
#  'The Computer Chronicles  Computers on Campus',
#  "The Computer Chronicles  Consumer Buyer's Guide",
#  'The Computer Chronicles  Flight Simulators',
#  'The Computer Chronicles  Handheld Computers',
#  'The Computer Chronicles  High Tech France Part 1',
#  'The Computer Chronicles  High Tech France Part 2',
#  'The Computer Chronicles  Home PCs',
#  'The Computer Chronicles  Hypercard',
#  'The Computer Chronicles  Hypertext',
#  'The Computer Chronicles  Input Devices',
#  'The Computer Chronicles  Low Cost Laser Printers',
#  'The Computer Chronicles  Memory Management',
#  'The Computer Chronicles  Optical Storage',
#  'The Computer Chronicles  Programming Languages',
#  'The Computer Chronicles  The Global Software Market',
#  'The Computer Chronicles  Video Game Consoles',
#  'The Computer Chronicles  Windows 3.0',
#  'Balla coi lupi',
#  'Django',
#  "I Quattro dell'Apocalisse",
#  'Il buono il brutto il cattivo  1966',
#  'Il Grande Silenzio 1968',
#  'Keoma',
#  'La Resa Dei Conti',
#  'Per qualche dollaro in più 1965',
#  'Per un pugno di dollari']

# %%
TMDB_API_KEY = 'fc134c5992c565508575ff65e3ce04de'
BASE_URL = 'https://api.themoviedb.org/3/'

# %%
# for movie in movie_list:
#     get_movie_details(movie)

# %%
def append_no_result_data(data_dict, title):
    """
    Helper function to append "no result" data to the movies_data dictionary.
    """
    data_dict['title'].append(title)
    data_dict['release_year'].append('')
    data_dict['director'].append('')
    data_dict['genre'].append('')
    data_dict['duration_minutes'].append('')
    data_dict['country_of_production'].append('')
    data_dict['language'].append('')
    data_dict['main_actors'].append('')
    data_dict['rating'].append('')
    data_dict['synopsis'].append('')
    data_dict['Seen'].append('')  # Placeholder for manual input
    data_dict['Subtitles'].append('')  # Placeholder for manual input

# %%
def get_movie_details(titles):
    # Create an empty dictionary to hold the details of all movies
    movies_data = {
        'file_title': [],
        'title': [],
        'release_year': [],
        'director': [],
        'genre': [],
        'duration_minutes': [],
        'country_of_production': [],
        'language': [],
        'main_actors': [],
        'rating': [],
        'synopsis': [],
        'Seen': [],
        'Subtitles': []
    }

    for title in titles:
    # Format the file title
        formatted_title = title.lower().capitalize()
        movies_data['file_title'].append(formatted_title)

        # Attempt to extract the year from the title
        year_match = re.search(r'(\d{4})', title)
    
        # Check if title is entirely numeric and if it's 4 digits long
        if title.isdigit() and len(title) == 4:
            year = ''
            clean_title = title
        else:
            year = year_match.group(1) if year_match else ''
            clean_title = title.replace(year, '').strip()

        search_url = f"{BASE_URL}search/movie?api_key={TMDB_API_KEY}&query={clean_title}"
        response = requests.get(search_url).json()

        # If we find results
        if response['results']:
            if year:  # if a year is given
                filtered_results = [result for result in response['results'] if year in result['release_date']]
                if not filtered_results:
                    movie_id = None
                else:
                    movie_id = filtered_results[0]['id']
            else:
                movie_id = response['results'][0]['id']

            if movie_id:  # If a valid movie_id is found
                # Fetching general movie details
                movie_url = f"{BASE_URL}movie/{movie_id}?api_key={TMDB_API_KEY}"
                movie_data = requests.get(movie_url).json()

                # Fetching movie credits for director information
                credits_url = f"{BASE_URL}movie/{movie_id}/credits?api_key={TMDB_API_KEY}"
                credits_data = requests.get(credits_url).json()

                # Extracting director's name
                director = next((member['name'] for member in credits_data['crew'] if member['job'] == 'Director'), None)

                # Adding details to the movies_data dictionary
                movies_data['title'].append(movie_data.get('original_title', 'N/A'))
                movies_data['release_year'].append(movie_data.get('release_date', 'N/A').split('-')[0])
                movies_data['director'].append(director if director else 'N/A')
                movies_data['genre'].append(', '.join([g['name'] for g in movie_data['genres']]) if movie_data.get('genres') else 'N/A')
                movies_data['duration_minutes'].append(movie_data.get('runtime', 'N/A'))
                movies_data['country_of_production'].append(movie_data['production_countries'][0]['name'] if movie_data.get('production_countries') else 'N/A')
                movies_data['language'].append(movie_data.get('original_language', 'N/A'))
                movies_data['main_actors'].append(', '.join([c['name'] for c in credits_data['cast'][:3]]) if credits_data.get('cast') else 'N/A')
                movies_data['rating'].append(movie_data.get('vote_average', 'N/A'))
                movies_data['synopsis'].append(movie_data.get('overview', 'N/A'))
                movies_data['Seen'].append('')  # Placeholder for manual input
                movies_data['Subtitles'].append('')  # Placeholder for manual input
            else:  # If the filtered results don't match the year or no valid movie ID
                append_no_result_data(movies_data, title)
        else:  # If no results are found at all
            append_no_result_data(movies_data, title)

    return movies_data

# %%
movies = get_movie_details(movie_list)

# %%
def save_to_csv(movies_data, csv_path):
    """
    Saves the movies data to a CSV file. If the CSV file already exists,
    it appends the new data without adding duplicates based on the 'title' column.
    """
    # If the CSV file exists, read it
    if os.path.exists(csv_path):
        existing_df = pd.read_csv(csv_path)
    else:
        existing_df = pd.DataFrame()

    # Convert the movies_data dict to a DataFrame
    new_df = pd.DataFrame(movies_data)

    # Append the new data to the existing data without adding duplicates
    combined_df = pd.concat([existing_df, new_df]).drop_duplicates(subset=['title','release_year']).reset_index(drop=True)

    # Save the combined data back to the CSV file
    combined_df.to_csv(csv_path, index=False)

# %%
# Usage:
# Assuming movies_data contains the data you want to save and "movies.csv" is your file
save_to_csv(movies, "movies.csv")
