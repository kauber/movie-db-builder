# %%
import pandas as pd

# %%
movies = pd.read_csv('movies_db.csv')

# %%
movies.shape
# Out:
# (545, 13)

# %%
movies[movies.director=='Mario Bava']
# Out:
#                          file_title                           title  \
# 26                  Cani arrabbiati                 Cani arrabbiati
# 322            Terrore nello spazio            Terrore nello spazio
# 332  5 Bambole per la Luna d'Agosto  5 bambole per la luna d'agosto
# 347    La ragazza che sapeva troppo    La ragazza che sapeva troppo
# 358       Sei Donne Per L'Assassino       Sei donne per l'assassino
# 406             La Casa Del Diavolo               Lisa e il diavolo
# 470         I Tre Volti della Paura         I tre volti della paura
# 471     Il rosso segno della follia     Il rosso segno della follia
# 472            La Frusta e il Corpo            La frusta e il corpo
# 473   La maschera del demonio, 1960         La maschera del demonio
# 474                Operazione paura                Operazione paura
#
#      release_year    director                      genre  duration_minutes  \
# ...

# %%
movies[movies.release_year==1970]
# Out:
#                                             file_title  \
# 27                              Il Caso Venere Privata
# 30                         La morte risale a ieri sera
# 54                                   I senza nome 1970
# 71                    Ultimo Domicilio Conosciuto 1970
# 126                              Lo chiamavano Trinità
# 136                   Venga a prendere il caffe da noi
# 209                                Cinque pezzi facili
# 295                                      Uomini Contro
# 297                      Il Giardino dei Finzi Contini
# 302  Indagine Su Un Cittadino Al Di Sopra Di Ogni S...
# 332                     5 Bambole per la Luna d'Agosto
# 460            L'Uccello Dalle Piume Di Cristallo 1970
# 471                        Il rosso segno della follia
#
#                                                  title  release_year  \
# 27                                        Cran d'arrêt        1970.0
# ...

# %%
movies.director.nunique()
# Out:
# 308

# %%
movies.groupby('director')['director'].count().sort_values(ascending=False).head(15)
# Out:
# director
# Alfred Hitchcock       14
# Mario Bava             11
# Nanni Moretti          10
# Ingmar Bergman          9
# Woody Allen             9
# Ermanno Olmi            9
# Dario Argento           9
# Pupi Avati              9
# Lucio Fulci             8
# Pier Paolo Pasolini     6
# David Cronenberg        6
# Umberto Lenzi           6
# Stanley Kubrick         6
# Fernando Di Leo         6
# Vittorio De Sica        5
# Name: director, dtype: int64

# %%
movies.groupby('release_year')['release_year'].count().sort_values(ascending=False).head(15)
# Out:
# release_year
# 1972.0    35
# 1971.0    24
# 1976.0    21
# 1975.0    17
# 1973.0    16
# 1985.0    14
# 1977.0    14
# 1970.0    13
# 1963.0    12
# 1974.0    12
# 2007.0    11
# 1969.0    10
# 1968.0    10
# 2003.0    10
# 1984.0    10
# Name: release_year, dtype: int64
